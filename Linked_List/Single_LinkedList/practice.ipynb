# %%
class Node :
    def __init__(self,data):
        self.data = data
        self.next = None
        
class SLL:
    def __init__(self):
        self.head = None
        
    def insert_at_beggining(self , data ):
        new  = Node(data)
        new.next = self.head 
        self.head = new 
        
    def insert_at_end(self , data ):
        new = Node(data)
        temp = self.head
        while temp.next :
            temp = temp.next 
        temp.next = new
        
    def spec(self,pos,data):
        new = Node(data)
        temp = self.head 
        
        for i in range(1,pos-1):
            temp = temp.next 
            
        new.next = temp.next 
        temp.next = new 
    def traverse(self):
        temp = self.head
        while temp:
            print(temp.data)
            temp = temp.next 
            
            

n = Node(10)
n1 = Node(20)
n2= Node(60)
n3 = Node(30)
n4 = Node(40)

l = SLL()
l.head = n 
n.next = n1
n1.next = n2
n2.next = n3
n3.next = n4

l.insert_at_beggining(1993)
l.insert_at_end(999999)
l.spec(5,13)
l.traverse()
# Out:
# 1993
# 10
# 20
# 60
# 13
# 30
# 40
# 999999

# %%
class Node :
    def __init__(self,data):
        self.data = data
        self.next = None
        
class SLL:
    def __init__(self):
        self.head = None
        
    def delete_beg(self):
        self.head = self.head.next
        
    def delete_end(self):
        temp = self.head.next
        prev = self.head
        
        while temp.next:
            temp = temp.next 
            prev = prev.next 
            
        prev.next = None
        
    def delete_spec(self,pos):
        temp = self.head.next 
        prev = self.head
        
        for i in range(1,pos-1):
            temp = temp.next 
            prev = prev.next 
        prev.next = temp.next 
        temp.next = None
    def traverse(self):
        temp = self.head
        while temp:
            print(temp.data)
            temp = temp.next 
            
            

n = Node(10)
n1 = Node(20)
n2= Node(60)
n3 = Node(30)
n4 = Node(40)

l = SLL()
l.head = n 
n.next = n1
n1.next = n2
n2.next = n3
n3.next = n4
# l.delete_beg()
l.delete_end()
# l.delete_spec(3)
l.traverse()

# %% [markdown]
# ALL

# %%
class Node :
    def __init__(self,data):
        self.data = data
        self.next = None
def to_array(array):
    if not array:
        return None
    head = Node(array[0])
    temp = head 
    for i in range(1,len(array)):
        new  = Node(array[i])
        temp.next  = new 
        temp = new 
    return head 

a= [1,3,5,246,63]
arr = to_array(a)
while arr:
    print(arr.data)
    arr = arr.next
# Out:
# 1
# 3
# 5
# 246
# 63

# %%
# Define a node class
class Node :
    def __init__(self, data):
        self.data = data
        self.next = None
        
# Define a function to convert an array to a linked list
def array_to_linked_list(array):
    
    # If the array is empty, return None
    if not array:
        return None
    # Create a head node with the first element of the array
    head = Node(array[0])
    
    # Keep track of the temp node
    temp = head 
    
    # Loop through the rest of the array elements
    for i in range (1,len(array)):
        new_node = Node(array[i]) # Create a new node with the temp element
        temp.next = new_node # Link the current node to the new node
        temp = new_node  # Update the current node to the new node
        
    return head    # Return the head node of the linked list

array = [1,2,3,4,5]

linked_list = array_to_linked_list(array)

while linked_list :
    print(linked_list.data)
    linked_list = linked_list.next

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class sll :
    def __init__(self):
        self.head = None 
        
    def insert_beg(self, data):
        new = Node(data)
        new.next = self.head 
        self.head = new 
    
        
        
    print('*'*40)
    
    
    def insert_end(self,data):
#         new = Node(data)
#         temp = self.head 
#         while temp.next:
#             temp = temp.next 

#         temp.next = new
        
        new = Node(data)
        temp = self.head
        while temp.next :
            temp = temp.next 
        temp.next = new
        
    def insert_spec (self , pos, data):
        new = Node(data)
        temp = self.head
        for i in range(pos-1):
            temp = temp.next 
            
        new.next = temp.next 
        temp.next = new
            
            
        
    def del_beg(self):
        self.head = self.head.next
        
    def del_end(self):
        temp = self.head.next
        prev = self.head
        while temp.next :
            temp = temp.next 
            prev = prev.next
        prev.next = None
            
    def del_spec(self , pos):
        temp= self.head.next 
        prev = self.head
        
        for i in range(pos-1):
            temp = temp.next 
            prev = prev.next 
            
        prev.next = temp.next 
        temp.next = None
            
        
        
    def traverse (self):
        temp = self.head
        while temp:
            print(temp.data)
            temp = temp.next
                        

n = Node(10)
n1= Node(20)
n2 = Node(500)
n3 = Node(40)

l = sll()

l.head = n
n.next = n1
n1.next = n2
n2.next = n3

l.insert_beg(111)
l.insert_end(999)
l.insert_spec(3,13)
l.del_beg()
l.del_spec(2)
l.del_end()

l.traverse()
# Out:
# ****************************************
# 10
# 20
# 500
# 40

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
def to(array):
    head = Node(array[0])
    temp = head
    for i in range(len(array)):
        new = Node(array[i])
        temp.next = new
        temp = new
        
    return head 


array = [12,32,123,2,2]

ar = to(array)
while ar:
    print(ar.data)
    ar = ar.next
# Out:
# 12
# 12
# 32
# 123
# 2
# 2

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class SLL_ :
        def __init__(self):
            self.head = None
        
        def i_b(self , data):
            new = Node(data)
            new.next = self.head
            self.head = new 
            
        def i_s(self,pos,data):
            new = Node(data)
            temp = self.head 
            for i in range(1,pos-1):
                temp = temp.next 
            new.next = temp.next 
            temp.next = new
            
        def i_e(self , data):
            new = Node(data)
            
            temp = self.head 
            while temp.next :
                temp = temp.next 
            temp.next  = new 
            
        def print_in_reverse_order(self):
            elements = []
            current = self.head
            while current:
                elements.insert(0, current.data)
                current = current.next

            for element in elements:
                print(element, end=' ')
            print()

            
        def traverse(self):
            temp = self.head
            
            while temp:
                print(temp.data)
                temp = temp.next 
    
            
n = Node(10)
n1= Node(20)
n2 = Node(500)
n3 = Node(40)

l = SLL_()

l.head = n
n.next = n1
n1.next = n2
n2.next = n3

l.i_b(111)
l.i_s(2,4643)
l.i_e(5423)
l.print_in_reverse_order()

# l.traverse()
# Out:
# 5423 40 500 20 10 4643 111
