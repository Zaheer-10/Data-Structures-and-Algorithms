# %% [markdown]
# Queue implementation using list

# %%
def enqueue():
    n = int(input("Enter the elements to be inserted"))
    queue.append(n)
    
    
def dequeue():
    if len(queue) ==0 :
        print('queue is empty ')
    else:
        print(queue[0], 'is the element deleted from queue')
        del queue[0]
        

def display():
    if len(queue) ==0 :
        print('queue is empty ')
    else:
        print("Elements of queue are")
        for i in queue:
            print(i,end='')
            print()
        print("Front of the queue is ",queue[0])
        print()
        print("Rear of the queue is ",queue[-1])








queue = list()

while(1):
    print("Enter the options Below : \n1-Enque \n2-Dequeue \n3-Display \n4-Exit")
    options = int(input())
    
    if options == 1:
        print("Enqueue Operations")
        enqueue()
        
    elif options == 2:
        print("Dequeue Operations")
        dequeue()
        
    elif options == 3:
        print("Display")
        display()
    else:
        break
# Out:
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 1
# Enqueue Operations
# Enter the elements to be inserted635
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 1
# Enqueue Operations
# Enter the elements to be inserted65845
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 1
# Enqueue Operations
# Enter the elements to be inserted895556
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 1
# Enqueue Operations
# Enter the elements to be inserted88945
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 1
# Enqueue Operations
# Enter the elements to be inserted30
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 1
# Enqueue Operations
# Enter the elements to be inserted40
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 1
# Enqueue Operations
# Enter the elements to be inserted9723
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 1
# Enqueue Operations
# Enter the elements to be inserted1000000
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 1
# Enqueue Operations
# Enter the elements to be inserted654
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 3
# Display
# Elements of queue are
# 635
# 65845
# 895556
# 88945
# 30
# 40
# 9723
# 1000000
# 654
# Front of the queue is  635
#
# Rear of the queue is  654
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 2
# Dequeue Operations
# 635 is the element deleted from queue
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 2
# Dequeue Operations
# 65845 is the element deleted from queue
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 2
# Dequeue Operations
# 895556 is the element deleted from queue
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 3
# Display
# Elements of queue are
# 88945
# 30
# 40
# 9723
# 1000000
# 654
# Front of the queue is  88945
#
# Rear of the queue is  654
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 3
# Display
# Elements of queue are
# 88945
# 30
# 40
# 9723
# 1000000
# 654
# Front of the queue is  88945
#
# Rear of the queue is  654
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 2
# Dequeue Operations
# 88945 is the element deleted from queue
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 3
# Display
# Elements of queue are
# 30
# 40
# 9723
# 1000000
# 654
# Front of the queue is  30
#
# Rear of the queue is  654
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 2
# Dequeue Operations
# 30 is the element deleted from queue
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 3
# Display
# Elements of queue are
# 40
# 9723
# 1000000
# 654
# Front of the queue is  40
#
# Rear of the queue is  654
# Enter the options Below :
# 1-Enque
# 2-Dequeue
# 3-Display
# 4-Exit
# 4
